# %% [markdown]
# <a href="https://colab.research.google.com/github/IPorteniu/CC184-Project/blob/master/TrabajoParcial_Complejidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Trabajo Parcial Complejidad Algoritmica**
#
# **Integrantes:**
#
#
# *   Luis Ordóñez u201810504
# *   Geampier Siguas u201815917
# *   William Angulo u201817762

# %% [markdown]
# ##**Introducción**

# %% [markdown]
# Años atrás, específicamente en el sigo XIX, Charles Babbage programó un motor para jugar ajedrez y años después construyó una maquina para jugar 3 en raya. Para el desarrollo de juegos se necesita el dominio en temas como inteligencia artificial, complejidad algorítmica para la resolución de problemas y también de optimizaciones para obtener una gran solución.
#
# Hoy en día, en las computadoras existen juegos mucho más complejos, algorítmicamente hablando, en comparación a como fue desarrollado el ajedrez en el siglo 19 estos juegos hacen uso de motores gráficos más exigentes a nivel de hardware. Los mismos hacen uso de un gran numero de algoritmos para optimizar la construcción de polígonos y la generación de sombras para obtener un resultado espectacular.
#
# Para el desarrollo del presente trabajo se tiene el fin de programar Quoridor, creado en Francia en el año 1997, nuestro objetivo consta de poder aplicar algoritmos. A diferencia de los juegos actuales, nuestros algoritmos no van dirigidos a mejorar las gráficas ni el sonido del videojuego, sino, apuntamos a implementar estructuras de datos y algoritmos para la optimización de uso de recursos y tiempo de ejecución para las jugadas del BOT contrincante.
#
# Por último, en este trabajo aplicaremos los conocimientos adquiridos durante el curso de Complejidad algorítmica para asegurarnos que los algoritmos elegidos cumplen con nuestros requerimientos como equipo y los que nos propone el curso.

# %% [markdown]
# ##**Estado del arte**

# %% [markdown]
# El analisis del estado del arte que aqui se realiza se agrupan en dos tipos. La primera, es sobre el Dominio y Conceptos generales de Quoridor , adjuntando investigaciones realizadas para la implementacion de este, mientras que la segunda parte, es sobre su conexión con la complejidad algoritmica y dominio de grafos.

# %% [markdown]
# **INVESTIGACIONES INTERNACIONALES:**
#
# * **DOMINAR EL QUORIDOR**
#
#  G, L. (2005, mayo). Mastering Quoridor (N.o 1). The University of New Mexico. https://pdfs.semanticscholar.org/acad/6962a9bb3eb3fde4272f476d6625eb0a8182.pdf?_ga=2.44123491.672833863.1600547763-1068031882.1600547763
#
#  **Objetivo :**  En este trabajo se analiza el juego de mesa Quoridor y se describe el desarrollo de un programa capaz de jugar a
# Quoridor. Dado que no existe una exigencia de conocimiento experto sobre el juego de Quoridor, el conjunto de
# características útiles del ghaamsenot aún no se ha definido. Por lo tanto, en este documento se proponen una serie de
# características. se utilizó un algoritmo ético
# para optimizar los pesos de una evaluación ponderada lineal ftu sobre estas características. los
# eficacia de este algoritmo genético como un método de aprendizaje o se evalúa. La resultante
# Quoridor arti fi cial player es capaz de jugar adecuadamente, butt w lo suficiente para vencer a un humano
# jugador.
#
#  **Características de Quoridor :** Para utilizar una función de evaluación heurística, se deben identificar las características del juego. Dado que Quoridor es un juego prácticamente desconocido en la literatura sobre juegos,
# no había una reserva de conocimiento experto al que recurrir, como se hacía en otros programas de juego. Por lo tanto, propuse una serie de características a partir de la observación del juego.
#
#  **Algoritmos de búsqueda de rutas :** Una característica obvia de Quoridor está relacionada con el objetivo del juego: mover tu peón al otro lado del tablero. Un indicador de lo bien que le va a un jugador es cuántas
# cuadrados de distancia entre el peón de ese jugador y la portería de ese jugador. El objetivo de un jugador se define como la fila o columna de cuadrados en el lado opuesto del tablero desde donde ese jugador
# peón comenzó el juego. El objetivo del jugador negro son las casillas a1, b1, c1, d1, e1,
# f1, g1, h1, i1, y el objetivo del jugador blanco son las casillas a9, b9, c9, d9,
# e9, f9, g9, h9, i9. Debido a que los algoritmos óptimos de búsqueda de rutas pueden ser costosos, yo
# considera una variedad de características relacionadas con la búsqueda de caminos que varían en precisión y rendimiento.
# Como se discutió en la Sección 2.4, a menudo existe una compensación entre la precisión de la evaluación
# función y profundidad de la búsqueda.
# La característica relacionada con la ruta más simple que utilicé fue un valor booleano que representa si el
# El peón está en el lado de la portería del tablero. Este valor es 1 si el jugador
# El peón está en una casilla en el lado de la portería, de lo contrario es un 0.
#
#   **Implementación :** Para desarrollar un reproductor artificial de Quoridor, tuve que desarrollar un algoritmo de búsqueda, una función de evaluación y un algoritmo de aprendizaje. Para la búsqueda de un algoritmo, me basé en un algoritmo de búsqueda negamax alfa-beta de profundización iterativa estándar con algunas modificaciones. La primera modificación fue hacer un cortocircuito en la búsqueda si una búsqueda de una capa revelaba un estado terminal ganador, porque no tiene sentido buscar más en el árbol si el agente está a un paso de ganar.
# Otra modificación fue el uso de una variación principal, que es una lista de tripletes (estado, movimiento, valor) que representan un camino a través del árbol. La función NEGAMAXVALUE se modificó para devolver una variación principal en lugar de solo el valor. El director
# la variación devuelta representa la ruta óptima desde el estado hasta el nodo hoja de la búsqueda.
# El uso de una variación principal cumplió varias funciones. La primera fue evitar bucles en el árbol del juego, por ejemplo, volver a un estado anterior. Con una variación principal, un estado puede verificar si alguno de sus estados secundarios es idéntico a alguno de sus estados principales. Si es así, el estado puede podar a esos niños.
#
#   **Resultados :** El proceso de aprendizaje duró algunas semanas hasta que se alcanzó una fecha límite. Durante este tiempo,
# algunas poblaciones obtuvieron más tiempo de CPU (debido al tiempo de inactividad de la máquina, error humano, etc.) que
# otros, por lo que el trabajo dedicado al aprendizaje no fue igual para cada población. Además, las poblaciones corrían en diferentes máquinas con diferentes velocidades. La figura 4.1 muestra el cambio en
# aptitud de la población (ver Sección 3.4) durante el proceso de aprendizaje. El eje X es la generación
# número del algoritmo genético en una escala logarítmica, y el eje Y es el porcentaje de
# juegos ganados contra la población de prueba. La aptitud de la población de la mayoría de las poblaciones parece
# haber alcanzado un pico temprano y luego haber caído o nivelado.
# A continuación, eché un vistazo a la aptitud individual de cada cromosoma en cada población.
# Elegí un cromosoma para representar a cada población, eligiendo el cromosoma con la
# mayor aptitud de su población. Estos cromosomas formaron una nueva población campeona.
# Los pesos de cada característica de estos cromosomas elegidos, nombrados por la población que
# representan, se muestran en la Tabla 4.1 y se representan en la Figura 4.2. La descripción de cada
# la abreviatura y el número de la función se pueden encontrar en la Sección 3.4. La figura 4.2 también muestra
# valor medio de cada peso en la población campeona.
#
#   **Conclusiones :** Los objetivos de este proyecto de investigación fueron analizar las características del juego de Quoridor, proponer características para usar en una función de evaluación, utilizar un algoritmo de aprendizaje para optimizar
# los pesos de una función de evaluación lineal, y evaluar el jugador artificial producido por
# este método.
# Como juego, Quoridor se puede caracterizar como determinista, secuencial, partizan,
# Loopy, dos jugadores, juego de suma cero de información perfecta con un resultado restringido. los
# El árbol de juego de Quoridor tiene un factor de ramificación máximo de 133 (128 posibles ubicaciones de cercas y 5 posibles ubicaciones de movimiento de peones), y un factor de ramificación mínimo de 1.
#
#  El objetivo de la investigación futura en esta área
# debería ser producir un jugador artificial Quoridor que pueda jugar competitivamente con los humanos.
# Aunque el factor de ramificación es bastante grande, todavía es posible utilizar el método bruto
# Forzar el enfoque de búsqueda para desarrollar un programa de juego eficaz. Investigaciones adicionales en este
# área podría investigar un algoritmo de búsqueda más eficiente y una heurística de poda. Caracteristicas
# que se proponga centrarse en la colocación estratégica de vallas. Mejorar la precisión de la función de evaluación también podría aumentar drásticamente la capacidad de la
# jugador. Se podría utilizar un algoritmo de aprendizaje de peso diferente, tal vez con un
# función de evaluación. La arquitectura servidor-cliente de mi código podría utilizarse para permitir
# el jugador artificial para aprender jugando a los humanos a través de Internet. Sin fecha límite
# Los límites de tiempo mucho más largos para aprender y jugar mejorarían al jugador artificial.
#
#  **Imágenes Adjuntas**

# %% [markdown]
# ![5.png](data:image/png;base64,...)![6.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)![2.png](data:image/png;base64,...)![3.png](data:image/png;base64,...)

# %% [markdown]
# * **BÚSQUEDA DE ÁRBOLES DE MONTE CARLO PARA QUORIDOR**
#
#  M, V., B, J., & A, H. (2018, septiembre). Monte Carlo Tree Search for Quoridor (N.o 1). Laboratorio de desarrollo de juegos, Universidad de Innopolis. https://www.researchgate.net/publication/327679826_Monte_Carlo_Tree_Search_for_Quoridor
#
#  **Objetivo :**  Este artículo presenta un estudio preliminar utilizando Monte Carlo Tree Search
# (MCTS) sobre el juego de mesa de Quoridor. Quoridor es un juego interesante
# para la expansión de agentes de jugador en MCTS debido a que tiene un
# conjunto de reglas mecánicamente simple, sin embargo, Quoridor tiene una
# complejidad de espacio de estado similar al Ajedrez con una mayor complejidad
# de árbol de juego. Se muestra que el sistema funciona bien contra los métodos
# existentes actuales, derrotando a un conjunto de agentes de jugadores extraídos
# de una implementación digital existente, así como un método anterior que usa un
# GA
#
#  **Introducción :** Monte Carlo Tree Search (MCTS) (Coulom 2006) (Kocsis y Szepesv´ári
# 2006) es una técnica muy conocida en estos días (Browne, CB et al. 2012)
# debido a los eficientes resultados obtenidos en el juego de mesa. Vamos ( Silver
# D. y col.
# 2016). Este juego produce dificultad para que un experto en IA cree un
# agente, debido a su complejidad espacial, factor de ramificación y dificultades
# para evaluar el estado del juego en el medio. Para hacer frente a estos, se
# utilizó la búsqueda de árbol de Monte Carlo debido a sus siguientes
# propiedades. Usa UCT ( Upper Con fi dence Bound aplicado a Trees) (Gelly et
# al. 2006) para evaluar los estados finales del juego. Además, consta de
# implementaciones de Monte Carlo, que se explican más adelante en la
# Sección V, para estimar el valor de cada estado en el árbol de búsqueda. A
# medida que el árbol crece, se generan valores más precisos. El promedio de
# estos despliegues puede proporcionar una evaluación de posición efectiva
# logrando un desempeño preciso en juegos como Backgammon (Tesauro y
# Galperin 1997) y Scrabble (Sheppard 2002). Este artículo presenta la
# investigación sobre el juego de mesa Quoridor para desarrollar un agente de
# jugador artificial utilizando el algoritmo de búsqueda de árbol de Monte Carlo
# y lo compara con los agentes existentes actualmente.
#
#  **Jugabilidad :** El jugador está representado por un peón que comienza en el espacio
# central en los bordes opuestos del tablero, las líneas de base. El objetivo es
# ser el primer jugador en mover su peón de su lado al lado opuesto del
# tablero, la línea de fondo opuesta.
# La característica principal que hace que este juego sea interesante y táctico
# son sus vallas. Las vallas son piezas planas de dos espacios de ancho que
# se pueden colocar en la ranura entre los cuadrados del tablero. Las vallas
# tienen la capacidad de facilitar el progreso del jugador o bloquear el camino
# de los peones, que deben rodearlos. Cada jugador tiene diez vallas al
# comienzo del juego y, una vez colocadas, no se pueden mover ni quitar.
# Cada jugador en su turno puede elegir mover su peón o colocar una de sus
# vallas. Una vez que el jugador se queda sin vallas, su peón debe moverse.
# Los peones se mueven un cuadrado a la vez, horizontal o verticalmente,
# hacia adelante o hacia atrás. Cuando dos peones se enfrentan entre sí en
# casillas vecinas que no están separadas por una valla, el jugador al que le
# toca el turno puede saltar sobre el peón del oponente y colocarse detrás del
# peón del oponente, avanzando así una casilla adicional. Si hay una valla
# detrás del peón, el jugador puede colocar su peón a la izquierda o derecha
# del peón del oponente. No se puede saltar las vallas, incluso cuando se
# mueve lateralmente debido a que una valla está detrás de un peón saltado.  Las cercas se pueden colocar directamente entre dos espacios, en cualquier
# ranura que no esté ocupada por una cerca. Sin embargo, no se puede colocar
# una valla que corte el único camino restante de cualquier peón hacia la meta. El
# primer jugador que llega a uno de los 9 cuadrados de la línea base de su
# oponente es el ganador.
# No hay una notación oficial para Quoridor, por lo que para este proyecto
# usamos una notación de una comunidad de jugadores (Quoridor Strats 2014).
# La notación propuesta es similar a la notación algebraica de Ajedrez. Cada
# cuadrado recibe una designación única de letra y número. A cada columna se
# le da una letra AI y a cada fila se le asigna un número 1-9.
#
#  **Complejidad del juego :**
# Quoridor tiene la cantidad de formas posibles de determinar un límite superior
# rápido de complejidad, como movimientos de peones multiplicados por la
# cantidad de formas posibles de colocar las vallas. Como el tablero tiene ochenta
# y un casillas, podemos colocar el primer peón en cualquiera de ellas, y el
# segundo en ochenta, debido a que el primer peón ya está colocado en el tablero.
# tablero. Por tanto, el número total de posiciones, S pags, con dos peones viene
# dada por la siguiente ecuación: S p = 81 ∗ 80 = 6480
#
#  **Búsqueda del árbol de Monte Carlo :** El algoritmo de búsqueda de árboles de Monte Carlo se usa para construir
# el agente de IA para Quoridor, ya que parece ser un algoritmo eficiente
# para este tipo de juego de mesa y tamaño de árbol de juego. Es un
# algoritmo de búsqueda probabilística con una capacidad de decisión única
# debido a su eficiencia en entornos abiertos con una enorme cantidad de
# posibilidades. Para tratar el tamaño del árbol de juego, se aplica el método
# de Monte Carlo (Metropolis y Ulam 1949). Como se basa en un muestreo
# aleatorio de los estados del juego, no es necesario utilizar la fuerza bruta.
# Hemos construido un árbol de juego con un nodo raíz, luego se amplía con
# simulaciones aleatorias. En el proceso, mantenemos el número de veces que
# hemos visitado un nodo específico y una puntuación ganadora, que se utiliza
# para evaluar el estado del tablero. Al final, seleccionamos el nodo con mejores
# resultados y puntuaciones más altas.
# Este algoritmo consta de cuatro fases:
#  1. Selección: En esta fase inicial, el algoritmo comienza
# con un nodo raíz y selecciona un nodo hijo de modo que elija el nodo
# con la tasa de ganancia máxima. Para asegurarse de que cada nodo
# tenga la oportunidad de ser seleccionado y equilibrar la situación
# entre exploración y explotación √
# w yo + C ∗
# norte yo
# et al. 2006).
# en (t)
# norte yo
#  2. Expansión: Cuando ya no pueda aplicar UCT a
# encuentra el nodo sucesor, expande el árbol del juego generando
# todos los estados posibles desde el nodo hoja.
#  3. Simulación: Después de la expansión, el algoritmo elige
# un nodo al azar y simula el juego hasta el final, al azar para ambos
# jugadores.
#  4. Propagación inversa: Esta última fase consiste en la
# fechar los nodos según el resultado de la simulación. Evalúa el estado
# para determinar qué jugador ha ganado y recorre hacia arriba hasta la
# raíz incrementando los recuentos de visitas y las puntuaciones de las
# victorias, es decir, un recuento de si el jugador de esa posición ha
# ganado, de cada nodo visitado.
# El algoritmo sigue repitiendo estas cuatro fases hasta un número fijo
# de iteraciones. Cuanto mayor sea el número de iteraciones, más
# confiable se vuelve la estimación.
#
#  **Implementación :** Este proyecto está implementado en el lenguaje de programación Java, utilizando
# bibliotecas estándar. Esta sección explica las principales clases y estructuras de
# datos utilizadas.
# La clase Tablero Tiene toda la información relacionada con el juego de mesa,
# casillas, vallas y ambos jugadores. Todos los cuadrados se almacenan en un Lista
# de arreglo, y para navegar por el tablero, usamos un Mapa que cada clave es un
# cuadrado y devuelve un Conjunto de todos los cuadrados adyacentes a la clave.
# Para comprobar si se puede colocar una valla determinada, inicialmente
# comenzamos el juego con un Conjunto que contiene todos los lugares posibles en los
# que se puede colocar una valla en el tablero. Luego, cada vez que se coloca una
# cerca, actualizamos el Conjunto eliminando posiciones "prohibidas". Después de
# comprobar que la posición de esa cerca está dentro del Conjunto, debemos
# comprobar que ambos jugadores no estén completamente bloqueados para llegar a
# la línea de fondo del oponente. Por esto, un BFS ( Se aplica Breadth First Search) que
# encuentra el camino más corto a la meta para cada jugador y lo considera un
# movimiento ilegal si la distancia es indefinida.
#
#  **Ajustes experimentales :**
# Debido a la investigación limitada sobre el juego de Quoridor y a la ausencia de
# clasificaciones de Elo humanas, no podemos medir el nivel del agente a nivel mundial.
# Sin embargo, hemos intentado evaluar a nuestro jugador contra el autojuego con más
# pasos de simulación y contra otros tipos de agentes de jugadores para tener una idea
# de la habilidad del agente:
#  1. Agente de simulaciones de 120k:
# El agente predeterminado para ejecutar los experimentos usa MCTS con la
# heurística descrita anteriormente. Realiza 120000 simulaciones del juego
# por decisión.
#  2. Agente de simulaciones 60k:
# Este agente fue creado para ver la influencia en el número de simulaciones
# del juego por decisión. La única diferencia entre este agente y el indicado
# en la subsección UNA es que este agente está haciendo 60000
# simulaciones por decisión.
#
#  **Resultados :** Para seleccionar el Algoritmo Genético entre todos los cromosomas
# creados dentro de una población, realizamos un torneo que consiste en
# crear una población de 10 cromosomas y cada uno juega uno contra el
# otro. Esto nos dará la aptitud de los cromosomas. El número máximo de
# movimientos para evitar bucles infinitos se estableció en 120 y el tiempo de
# decisión en 10 segundos por movimiento. Para jugar contra nuestro agente
# de 120k tomamos los dos mejores cromosomas del torneo.
# En todos los experimentos realizados, nuestro jugador fue el Agente 120k
# predeterminado. El experimento con 60k Agent se realizó automáticamente
# para 250 juegos, ya que fue fácil adaptar el código para jugar contra sí mismo.
# Sin embargo, como no tenemos el código fuente de los agentes alternativos,
# los experimentos con todos ellos se hicieron manualmente, tomando los
# movimientos de nuestro agente y jugándolos contra los cuatro cerebros. En el
# proceso de evaluación, los primeros diez juegos se jugaron contra cada uno
# de los cuatro tipos de cerebro, cuando no había una situación de misericordia
# obvia, es decir, en el caso de Cerebro4, luego ampliamos esto a 100 juegos
# para permitir una evaluación estadística.
#
#  **Conclusiones :** Hemos creado un agente MCTS para el juego de mesa Quoridor y lo
# comparamos con varios tipos de agentes anteriores, incluida la
# reimplementación de un GA. Este trabajo de investigación completado hasta
# ahora se centra solo en la versión para dos jugadores, Quoridor se puede
# jugar con cuatro juegos.
#
#  **Imágenes Adjuntas**

# %% [markdown]
# ![figura 1.png](data:image/png;base64,...)

# %% [markdown]
# ![figura 2.png](data:image/png;base64,...)

# %% [markdown]
# * **APLICACIONES DE LA TEORÍA DE GRAFOS A ALGUNOS JUEGOS DE ESTRATEGIA**
#
#  M, E. (2004, junio). Aplicaciones de la teoría de grafos a algunos juegos de estrategia (N.o 1). Universidad Politécnica de Madrid. https://core.ac.uk/download/pdf/41553523.pdf
#
#  **Introducción :** Al analizar algunos juegos relativamente sencillos, podemos observar que es posible seguir una estrategia que nos permite ganar
# si jugamos bien. El propósito de este artículo es modelar estos juegos mediante la Teoría de Grafos, revisar las estrategias seguidas para ganar y aplicarlas a otros juegos que puedan ser igualmente modelables. Para ello es fundamental comprender el concepto de núcleo de un grafo, por lo que será preciso conocer algunas definiciones básicas de la Teoría de Grafos.
#
#  **Ideas básicas para la teoría de grafos :** Los conceptos fundamentales de la Teoría de Grafos los
# podemos encontrar en multitud de libros y artículos, por
# ejemplo en (Bollobás, 1998).Dibujar un grafo para resolver un problema es bastante
# común, y no se precisa de conocimientos matemáticos. Un
# grafo es un dibujo, y consta de vértices
# y de aristas que unen algunos de estos vértices. Se pueden modelar mediante grafos multitud de situaciones,
# como una red de carreteras que conectan ciudades, una red
# eléctrica, etc. En algunos casos es necesario imponer un sentido a las aristas, por ejemplo, si se quiere representar la red
# de las calles de una ciudad donde aparecen direcciones únicas
# (Ver figura 2). Uno de los más famosos es el de los puentes de
# Könisberg. Esta ciudad rusa que se encuentra a orillas del río
# Pregel, y que en el siglo XVIII tenía siete puentes, sirvió de
# pretexto para un famoso problema con grafos: se trataba de
# pasar por todos los puentes sin atravesar ninguno de ellos dos
# veces.
#
#  Definición: Un grafo es un par G = (V, E), donde V es el conjunto de vértices del grafo, siendo su cardinal |V| = n entero
# positivo, y E V x V son las aristas del grafo (e = {x, y} = {y, x}
# es una arista, por lo que no existe orientación).
#
#  **Análisis de Juegos :**
#  1. **Llegar a la meta :**
#  Se juega en una cuadrícula del tamaño que se desee; por fijar
# ideas, digamos que la cuadrícula es de 5 x 5. Una esquina, por
# ejemplo la superior izquierda, es la de salida y la esquina
# opuesta, por tanto la inferior derecha, es la de llegada. El juego se desarrolla por turnos. El primer jugador marca la
# casilla de salida y, a continuación, el segundo jugador marca
# otra casilla situada justo debajo, justo a la derecha o en diagonal (lo que equivale a mover una posición a la derecha y una
# posición abajo). Ahora el primer jugador hace lo mismo desde
# la marca hecha por su oponente y así sucesivamente. Gana el
# que consiga marcar la casilla señalada como Meta (naturalmente, se puede jugar a que quien marque la meta pierde).
# Este juego se puede modelar con un grafo dirigido en el que
# cada casilla es un vértice del grafo, y los arcos salen de una
# casilla a otra a la que sea posible moverse.Estrategia: Una vez más, las posiciones del núcleo nos darán
# la clave para ganar. Razonando como en el juego anterior, del
# final al principio en las etapas necesarias, podemos ir obteniendo los vértices que componen el núcleo del juego. Siempre resulta sencillo encontrar el núcleo de este juego para
# cualquier tamaño de cuadrícula tanto si gana como si pierde
# quien marque la meta.

# %% [markdown]
# ![1a.png](data:image/png;base64,...)![1b.png](data:image/png;base64,...)![1c.png](data:image/png;base64,...)

# %% [markdown]
# ##**Metodología**

# %% [markdown]
# Antes de empezar el proyecto el equipo se propuso investigar acerca de análisis de tiempos, para realizar una solución con gran eficiencia y también la aplicación de algoritmos de búsqueda en grafos para poder resolver una de las principales problematicas de Quoridor

# %% [markdown]
# ![diagrama-de-ishikawa.png](data:image/png;base64,...)

# %% [markdown]
# Entre las principales problematicas encontradas tenemos las 4 que pueden visualizarse en el gráfico de *Ishikawa*
#
# Para la investigación de que algoritmo de búsqueda era conveniente aplicar para encontrar el camino más corto se utilizó el libro del autor Thomas H. Cormen, INTRODUCTION TO ALGORITHMS. Para dicha elección se ha tenido en cuenta el analisis  de tiempos según la cantiadad de datos que se van a introducir en el ejercicio.

# %% [markdown]
# ##Espacio de búsqueda

# %% [markdown]
# Al intentar resolver este tipo de problemas, es necesario establecer una serie de pautas que ayudarán a determinar un orden en su resolución. Para ello, se establecerán una serie de simplificaciones, desde un punto de vista conceptual, que serán útiles para dejar las ideas un poco más claras, dejando así, de forma transitoria de lado la parte de implementación del algoritmo, para centrarnos exclusivamente en la idea de resolución del problema.
#
# En primer lugar, consideraremos en principio que el espacio de búsqueda es un grafo, lo que simplifica bastante las operaciones, ya que de este modo será posible generar un algoritmo que no recaiga en bucles infinitos, permitiendo así la posibilidad de ir almacenando los nodos visitados y cerrados para no repetir caminos, cosa que no se puede realizar usando búsqueda en árboles.Entonces el espacio de búsqueda representa todas las posibles soluciones candidatas a un problema, definiendolo como NxN el tamaño del tablero.
#
#
# ![sda.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ##Dijkstra Algorithm
#
# El algoritmo de Dijkstra, también llamado algoritmo de caminos mínimos, es un algoritmo para la determinación del camino más corto dado un vértice origen al resto de vértices en un grafo con pesos en cada arista. Su nombre se refiere a Edsger Dijkstra, quien lo describió por primera vez en 1959.
# La idea subyacente en este algoritmo consiste en ir explorando todos los caminos más cortos que parten del vértice origen y que llevan a todos los demás vértices; cuando se obtiene el camino más corto desde el vértice origen, al resto de vértices que componen el grafo, el algoritmo se detiene. El algoritmo es una especialización de la búsqueda de costo uniforme, y como tal, no funciona en grafos con aristas de costo negativo (al elegir siempre el nodo con distancia menor, pueden quedar excluidos de la búsqueda nodos que en próximas iteraciones bajarían el costo general del camino al pasar por una arista con costo negativo).
#
# Teniendo un grafo dirigido ponderado de N nodos no aislados, sea x el nodo inicial, un vector D de tamaño N guardará al final del algoritmo las distancias desde x al resto de los nodos.
#
# * 1. Inicializar todas las distancias en D con un valor infinito relativo ya que son desconocidas al principio, exceptuando la de x que se debe colocar en 0 debido a que la distancia de x a x sería 0.
# * 2. Sea a = x (tomamos a como nodo actual).
# * 3. Recorremos todos los nodos adyacentes de a, excepto los nodos marcados, llamaremos a estos vi.
# * 4. Si la distancia desde x hasta vi guardada en D es mayor que la distancia desde x hasta a sumada a la distancia desde a hasta vi; esta se sustituye con la segunda nombrada, esto es:
# si (Di > Da + d(a, vi)) entonces Di = Da + d(a, vi)
# * 5. Marcamos como completo el nodo a.
# * 6. Tomamos como próximo nodo actual el de menor valor en D (puede hacerse almacenando los valores en una cola de prioridad) y volvemos al paso 3 mientras existan nodos no marcados.
# Una vez terminado al algoritmo, D estará completamente lleno.
#
# ##A * Algorithm
#
# A* (pronunciado "A-star") es un algoritmode búsqueda de trazado y recorrido gráfico, que se utiliza a menudo en muchos campos de la informática debido a su integridad, optimización y eficiencia óptima.  Uno de los principales inconvenientes prácticos es su •estilo de visualización O(b-d-)O(b^d) complejidad del espacio, ya que almacena todos los nodos generados en la memoria. Por lo tanto, en los sistemas prácticos de enrutamiento de viajes,generalmente es superado por algoritmos que pueden preprocesar el gráfico para lograr un mejor rendimiento, así como enfoques limitados a la memoria; sin embargo, A* sigue siendo la mejor solución en muchos casos.
#
#
# ##Bellman Ford Algorithm
#
# El algoritmo de Bellman-Ford genera el camino más corto en un grafo dirigido ponderado (en el que el peso de alguna de las aristas puede ser negativo). El algoritmo de Dijkstra resuelve este mismo problema en un tiempo menor, pero requiere que los pesos de las aristas no sean negativos, salvo que el grafo sea dirigido y sin ciclos. Por lo que el Algoritmo Bellman-Ford normalmente se utiliza cuando hay aristas con peso negativo. Este algoritmo fue desarrollado por Richard Bellman, Samuel End y Lester Ford.
#
# Según Robert Sedgewick, “Los pesos negativos no son simplemente una curiosidad matemática; surgen de una forma natural en la reducción a problemas de caminos más cortos”, y son un ejemplo de una reducción del problema del camino hamiltoniano que es NP-completo hasta el problema de caminos más cortos con pesos generales. Si un grafo contiene un ciclo de coste total negativo entonces este grafo no tiene solución. El algoritmo es capaz de detectar este caso.
#
# Si el grafo contiene un ciclo de coste negativo, el algoritmo lo detectará, pero no encontrará el camino más corto que no repite ningún vértice. La complejidad de este problema es al menos la del problema del camino más largo de complejidad NP-Completo.

# %%
Algortimo Dijkstra

   DIJKSTRA (Grafo G, nodo_fuente s)       
       para u ∈ V[G] hacer
           distancia[u] = INFINITO
           padre[u] = NULL
           visto[u] = false
       distancia[s] = 0
       adicionar (cola, (s, distancia[s]))
       mientras que cola no es vacía hacer
           u = extraer_mínimo(cola)
           visto[u] = true
           para todos v ∈ adyacencia[u] hacer
               si ¬ visto[v]      
                   si distancia[v] > distancia[u] + peso (u, v) hacer
                       distancia[v] = distancia[u] + peso (u, v)
                       padre[v] = u
                       adicionar(cola,(v, distancia[v]))

Algoritmo A*Algorithm

function reconstruct_path(cameFrom, current)
    total_path := {current}
    while current in cameFrom.Keys:
        current := cameFrom[current]
        total_path.prepend(current)
    return total_path

// A* finds a path from start to goal.
// h is the heuristic function. h(n) estimates the cost to reach goal from node n.
function A_Star(start, goal, h)
    // The set of discovered nodes that may need to be (re-)expanded.
    // Initially, only the start node is known.
    // This is usually implemented as a min-heap or priority queue rather than a hash-set.
    openSet := {start}

    // For node n, cameFrom[n] is the node immediately preceding it on the cheapest path from start
    // to n currently known.
    cameFrom := an empty map

    // For node n, gScore[n] is the cost of the cheapest path from start to n currently known.
    gScore := map with default value of Infinity
    gScore[start] := 0

    // For node n, fScore[n] := gScore[n] + h(n). fScore[n] represents our current best guess as to
    // how short a path from start to finish can be if it goes through n.
    fScore := map with default value of Infinity
    fScore[start] := h(start)

    while openSet is not empty
        // This operation can occur in O(1) time if openSet is a min-heap or a priority queue
        current := the node in openSet having the lowest fScore[] value
        if current = goal
            return reconstruct_path(cameFrom, current)

        openSet.Remove(current)
        for each neighbor of current
            // d(current,neighbor) is the weight of the edge from current to neighbor
            // tentative_gScore is the distance from start to the neighbor through current
            tentative_gScore := gScore[current] + d(current, neighbor)
            if tentative_gScore < gScore[neighbor]
                // This path to neighbor is better than any previous one. Record it!
                cameFrom[neighbor] := current
                gScore[neighbor] := tentative_gScore
                fScore[neighbor] := gScore[neighbor] + h(neighbor)
                if neighbor not in openSet
                    openSet.add(neighbor)

    // Open set is empty but goal was never reached
    return failure
  
Algoritmo de Bellman Ford

  bool BellmanFord_Optimizado(Grafo G, nodo_origen s)
       // inicializamos el grafo. Ponemos distancias a INFINITO menos el nodo origen que
       // tiene distancia 0. Para ello lo hacemos recorriéndonos todos los vértices del grafo
       for v ∈ V[G] do
           distancia[v]=INFINITO
           padre[v]=NULL
       distancia[s]=0
       encolar(s, Q)
       en_cola[s]=TRUE
       while Q!=0 then
           u = extraer(Q)
           en_cola[u]=FALSE
           // relajamos las aristas
           for v ∈ ady[u] do
               if distancia[v]>distancia[u] + peso(u, v) then
                   distancia[v] = distancia[u] + peso (u, v)
                   padre[v] = u
                   if en_cola[v]==FALSE then
                       encolar(v, Q)
                       en_cola[v]=TRUE

# %% [markdown]
# ##Metricas

# %% [markdown]
# Para medir la eficiencia de los algoritmos se ha decidido tomar el tiempo promedio de cada uno de ellos al buscar todos los caminos posibles y elegir el más corto.

# %% [markdown]
# ##Test del algoritmo Dijkstra

# %%
tiempos = [0.0001136726803249783,0.0001081095814594184,0.00019590059916178385,0.00011070569356282552,0.00011081165737575955,0.002215703328450521]
import matplotlib.pyplot as plt
plt.plot(tiempos)
plt.ylabel('timepos')
plt.xlabel('nodos')
plt.show()

# %% [markdown]
# ##Test del algoritmo A*Astar

# %%
tiempos = [0.0003323554992675781,0.0003324614308051213,0.00033171971638997394,0.0003325409359402127,0.00022167629665798612]
import matplotlib.pyplot as plt
plt.plot(tiempos)
plt.ylabel('timepos')
plt.xlabel('nodos')
plt.show()

# %% [markdown]
# ##Test del algoritmo Bellman Ford

# %%
tiempos=[0.00408099861145,0.0436601924896,0.0480559158325,0.0194570922852,0.0386888885498,0.111295938492,0.0431129550934,0.462600040436,0.465167093277]
import matplotlib.pyplot as plt
plt.plot(tiempos)
plt.ylabel('tiempos')
plt.xlabel('nodos')
plt.show()

# %% [markdown]
# ##**Experimentos**
#
# Para la parte de experimentos, nuestro proyecto tuvo que pasar por una seria de procesos parala implementaion y desarrollo de los aglrotimos que han permitido que nuestra solcución final, cumpla con todos los parametros y sea eficiente al momento de su uso. Antes de dar incio con los algoritmos, el grupo comprobo en primer lugar, el funcionamiento del movimiento del peón, luego el funcionamiento de las paredes y como estas restringen el movimiento del peón pero dejandola solo en un supuesto teorico, ya que para la primera parte no se nos solicita la funcionalidad de las paredes.
#
# Se ha experimentado programando varias paredes, como un laberinto, para revisar si en realidad restrigian el movimiento del peón. Después de haber convalidado todo ello, se empezó a implementar los algoritmos para hacer que el peón encuentre el camino a su meta designada. Para los algoritmos como Dijkstra, se usó los métodos de recursividad basados en ejemplos vistos en las clases del curso de Complejidad Algoritmica, además de los valores creados que controlan los peones, paredes y el tablero.
#
# ##**Solución**
#
# En la solución implementada por el grupo, hemos desarrollado el trabajo utlizando los algortimos de Dijkstra Algorithm , A * Algorithm y Bellman Ford Algorithm que una vez implementados en el proyecto,  permiten al peón buscar un camino hacia su meta, ya sea de la forma más o menos óptima posible.

# %% [markdown]
# ##**Conclusiones**
#
#
# Durante el desarrollo del trabajo hemos aprendido lo importante que ha sido para la realización del proyecto el dominar temas como grafos y algoritmos de busqueda. El presente proyecto nos ha brindado la oportunidad de emprender la aventura de aprender un nuevo lenguaje y aplicar los conocimientos adquiridos desde semana 1 lo cual no ha sido para nada sencillo.
# Se han implementado diversos algoritmos para posteriormente analizar cada uno de sus costes con respecto a tiempo recursos.

# %% [markdown]
# ## Referencias

# %% [markdown]
# * Thomas H. Cormen, (2009) INTRODUCTION TO ALGORITHMS, United States of America
#
# * Aviezri S. Fraenkel and Ofer Rahat. Infinite cyclic impartial games. Lecture Notes
# in Computer Science, 1558:212–221, 1999.
#
# * Graham Kendall and Glenn Whitwell. An evolutionary approach for the tuning of a
# chess evaluation function using population dynamics. In Congress on Evolutionary
# Computation, pages 995–1002, 2001.
#
# * Qian Liang. The evolution of Mulan: Some studies in game-tree pruning and evaluation functions in the game of Amazons. Master’s thesis, University of New Mexico, 2003.
#
# * Browne, C. B. et al., 2012. A survey of monte carlo
# tree search methods. IEEE Transactions on Computational Intelligence and AI in games, 4, no. 1, 1–43.
#
# * Campbell M.S. and Marsland T.A., 1983. A comparison
# of minimax tree search algorithms. Artificial Intelligence, 20, no. 4, 347–367.
#
# * Coulom R., 2006. Efficient selectivity and backup operators in Monte-Carlo tree search. In International
#
# * Pearl J., 1982. The solution for the branching factor of
# the alpha-beta pruning algorithm and its optimality.
#
# * Communications of the ACM, 25, no. 8, 559–564.
# Quoridor Strats, 2014. Notation.
# Https://quoridorstrats.wordpress.com/notation/.
#
# * Sheppard B., 2002. World-championship-caliber Scrabble. Artificial Intelligence, 134, no. 1-2, 241–275.
#
# * Silver D. et al., 2016. Mastering the game of Go with deep neural networks and tree search. Nature, 529, 484–503. URL http://www.nature.com/nature/ journal/v529/n7587/full/nature16961.html.
#
# * Stockman G.C., 1979. A minimax algorithm better than alpha-beta? Artificial Intelligence, 12, no 2, 179–196.
#
# * Tesauro G. and Galperin G.R., 1997. On-line policy improvement using Monte-Carlo search. In Advances in Neural Information Processing Systems. 1068–1074. van Steenbergen M., 2006. Quoridor. online. Http://martijn.van.steenbergen.nl/projects/quoridor/.
